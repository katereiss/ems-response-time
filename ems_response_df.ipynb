# %%
import pandas as pd

# %%
df = pd.read_csv('EMS_Incident_Dispatch_Data.csv')
# Out:
# /Users/kate/opt/anaconda3/envs/metis/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#    CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        110010790  01/01/2011 02:19:47 AM               UNC
# 1        110010791  01/01/2011 02:19:49 AM               EDP
# 2        110010792  01/01/2011 02:19:52 AM            UNKNOW
# 3        110010793  01/01/2011 02:19:56 AM               UNC
# 4        110010794  01/01/2011 02:20:05 AM            INJURY
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                          2.0             UNC                        2.0
# 1                          7.0             EDP                        7.0
# 2                          3.0          UNKNOW                        3.0
# 3                          2.0             UNC                        2.0
# 4                          5.0          INJURY                        5.0
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0    01/01/2011 02:21:14 AM                              Y
# ...

# %%
df
# Out:
#          CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0              110010790  01/01/2011 02:19:47 AM               UNC
# 1              110010791  01/01/2011 02:19:49 AM               EDP
# 2              110010792  01/01/2011 02:19:52 AM            UNKNOW
# 3              110010793  01/01/2011 02:19:56 AM               UNC
# 4              110010794  01/01/2011 02:20:05 AM            INJURY
# ...                  ...                     ...               ...
# 7743105        162600854  09/16/2016 07:48:52 AM               UNC
# 7743106        162600856  09/16/2016 07:49:32 AM            MVAINJ
# 7743107        162600857  09/16/2016 07:50:02 AM              SICK
# 7743108        162600858  09/16/2016 07:50:32 AM             SEIZR
# 7743109          1626008                     NaN               NaN
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                2.0             UNC
# ...

# %%
df.sort_values('INITIAL_CALL_TYPE')
# Out:
#          CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 5637544        150983159  04/08/2015 08:39:52 PM            ABDPFC
# 7086813        160980282  04/07/2016 02:49:04 AM            ABDPFC
# 5903455        151651023  06/14/2015 06:20:52 AM            ABDPFC
# 7702966        162501376  09/06/2016 10:33:56 AM            ABDPFC
# 6768656        160162321  01/16/2016 03:15:54 PM            ABDPFC
# ...                  ...                     ...               ...
# 627231         111833172  07/02/2011 07:09:45 PM             VENOM
# 1382070        120351117  02/04/2012 09:27:13 AM             VENOM
# 5897516        151634488  06/12/2015 09:07:59 PM             VENOM
# 6755963        160130809  01/13/2016 08:25:20 AM             VENOM
# 7743109          1626008                     NaN               NaN
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 5637544                          5.0          ABDPFC
# ...

# %%
arrests = df.loc[df['FINAL_CALL_TYPE'] == 'ARREST']

# %%
arrest_transports = arrests.loc[arrests['INCIDENT_DISPOSITION_CODE'] == 82]

# %%
arrest_transports.to_csv('arrest_transports.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
arrests.tail(10000)
# Out:
#          CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 7044280        160870366  03/27/2016 02:30:54 AM            ARREST
# 7044370        160870462  03/27/2016 03:21:10 AM            ARREST
# 7044544        160870647  03/27/2016 04:47:07 AM            ARREST
# 7044557        160870660  03/27/2016 04:57:18 AM            ARREST
# 7044636        160870745  03/27/2016 05:44:01 AM            ARREST
# ...                  ...                     ...               ...
# 7742749        162600452  09/16/2016 03:45:05 AM            ARREST
# 7742955        162600690  09/16/2016 06:31:42 AM            ARREST
# 7742969        162600705  09/16/2016 06:37:59 AM            ARREST
# 7743006        162600748  09/16/2016 06:55:58 AM            ARREST
# 7743040        162600783  09/16/2016 07:13:46 AM            ARREST
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 7044280                          1.0          ARREST
# ...

# %%
arrests.tail(10000).to_csv('arrests.csv')

# %%
deaths = df.loc[df['INCIDENT_DISPOSITION_CODE'] == 83]

# %%
deaths
# Out:
#          CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 920            110011793  01/01/2011 05:07:06 AM            DIFFBR
# 1146           110012045  01/01/2011 06:06:03 AM            ARREST
# 1159           110012062  01/01/2011 06:09:07 AM               UNC
# 1266           110012184  01/01/2011 06:42:51 AM            ARREST
# 1281           110012202  01/01/2011 06:49:05 AM            ARREST
# ...                  ...                     ...               ...
# 7742410        162600083  09/16/2016 12:35:05 AM            ARREST
# 7742445        162600125  09/16/2016 12:51:56 AM            ARREST
# 7742893        162600610  09/16/2016 05:42:00 AM               UNC
# 7742955        162600690  09/16/2016 06:31:42 AM            ARREST
# 7743040        162600783  09/16/2016 07:13:46 AM            ARREST
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 920                              2.0          DIFFBR
# ...

# %%
deaths.FINAL_CALL_TYPE.unique()
# Out:
# array(['DIFFBR', 'ARREST', 'RESPIR', 'OTHER', 'UNC', 'CARD', 'UNKNOW',
#        'INJURY', 'INBLED', 'SICK', 'STATEP', 'EDP', 'DOA', 'PEDSTR',
#        'TRAUMA', 'OBLAB', 'ABDPN', 'JUMPDN', 'INHALE', 'SHOT', 'MCI21P',
#        'ASTHMB', 'DROWN', 'STAB', 'CVAC', 'BURNMA', 'MCI43P', 'MVAINJ',
#        'STNDBY', 'DRUG', 'CHOKE', 'ALTMEN', 'SEIZR', 'ELECT', 'INJMAJ',
#        'CHILDA', 'OBOUT', 'INJMIN', 'JUMPUP', 'PD13', 'ANAPH', 'MCI80P',
#        'GYNHEM', 'BURNMI', 'SICPED', 'MCI22P', 'CVA', 'SICMIN', 'SPEVNT',
#        'MCI30P', 'MCI34P', 'MCI40P', 'MCI59P'], dtype=object)

# %%
arrest_deaths = deaths.loc[deaths['FINAL_CALL_TYPE'] == "ARREST"]

# %%
arrest_deaths.to_csv('arrest_deaths.csv')
